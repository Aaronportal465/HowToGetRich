# %%
print("hello idiots")
# Out:
# hello idiots

# %%
print("Aaron is present and working")
# Out:
# Aaron is present and working

# %%
print("Vicky is also present :)")

# %%
print('I hate this - Sami')
# Out:
# I hate this - Sami
